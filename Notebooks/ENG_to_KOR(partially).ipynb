# %%
import numpy as np
import pandas as pd

# %%
유방암_환자_기본정보 = pd.read_csv("../Data/1. 유방암 Fake Data/유방암_환자_기본정보.csv",  encoding='CP949')
유방암_환자_기본정보.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호      초진일자    생년월일  진단시연령  수술시연령 환자성별코드 환자성별코드기타내용  \
# 0    30     IRB  P00001  20160119  197502     41     43      F        NaN
# 1    30     IRB  P00002  20151019  195101     64     65      F        NaN
# 2    30     IRB  P00003  20110617  196804     43     47      F        NaN
# 3    30     IRB  P00004  20160909  196606     50     56      F        NaN
# 4    30     IRB  P00005  20120712  194212     70     72      F        NaN
#
#                생성일시
# 0  2020-08-06 16:05
# 1  2020-08-06 16:05
# 2  2020-08-06 16:05
# 3  2020-08-06 16:05
# 4  2020-08-06 16:05

# %% [markdown]
# # 환자

# %%
유방암_환자_건강정보= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_환자_건강정보.csv",  encoding='CP949')
유방암_환자_건강정보.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호      기록일자  건강정보순번      입원일자      거주지내용      퇴원일자  \
# 0    30     IRB  P00001  20160119      79  20130504  부산광역시 강서구  20130609
# 1    30     IRB  P00002  20151019      25  20120527  부산광역시 강서구  20140826
# 2    30     IRB  P00003  20110617      63  20110315    강원도 인제군  20141106
# 3    30     IRB  P00004  20160909      59  20121004   경산북도 경산시  20150906
# 4    30     IRB  P00005  20120712       7  20110606  대구광역시 달서구  20150131
#
#    입원시연령  ABO혈액형코드  ... 출산자녀수  모유수유경험여부  수유기간월수 병력유방수술여부  병력유방수술상세내용  \
# 0     41         3  ...    28         Y      36        Y     1.자궁적출술
# 1     64         4  ...     5         N      17        Y     1.자궁적출술
# 2     43         2  ...    40         Y      18        Y     1.자궁적출술
# 3     50        99  ...    77         Y      19        Y     1.자궁적출술
# 4     70         4  ...    13         Y      24        N         NaN
#
#   경구피임약사용여부 경구피임약사용기간월수  HRT사용여부  HRT기간월수              생성일시
# 0         Y         9.0        N      NaN  2020-08-07 13:22
# 1         N         NaN        N      NaN  2020-08-07 13:22
# 2         N         NaN        N      NaN  2020-08-07 13:22
# 3         Y         9.0        N      NaN  2020-08-07 13:22
# 4         Y         2.0        N      NaN  2020-08-07 13:22
#
# [5 rows x 64 columns]

# %%
유방암_환자_가족력= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_환자_가족력.csv",  encoding='CP949')
유방암_환자_가족력.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호      기록일자  환자가족코드 환자가족코드기타내용      입원일자      퇴원일자  \
# 0    30     IRB  P00001  20160326       1   아버지 기타사항  20150403  20150528
# 1    30     IRB  P00002  20140322       1   아버지 기타사항  20130619  20140126
# 2    30     IRB  P00003  20150824       1   아버지 기타사항  20091017  20150630
# 3    30     IRB  P00004  20130216       1   아버지 기타사항  20090210  20090719
# 4    30     IRB  P00005  20160118       1   아버지 기타사항  20131229  20151124
#
#   환자가족병력여부 환자가족병력고혈압여부 환자가족병력당뇨여부 환자가족병력결핵여부 환자가족병력간질환여부 환자가족병력암여부  \
# 0        N           Y          N          Y           N         N
# 1        N           N          N          N           Y         Y
# 2        Y           N          N          Y           N         N
# 3        N           N          N          N           Y         Y
# 4        Y           N          N          N           Y         Y
#
#    환자가족암병력암종코드 환자가족암병력암종코드기타내용 환자가족병력기타여부   환자가족병력기타내용              생성일시
# 0            7       전립선  기타사항          N  전립선비대증으로 수술  2020-08-07 10:23
# 1           10        췌장  기타사항          N     췌장암으로 수술  2020-08-07 10:23
# 2           10        췌장  기타사항          Y     췌장암으로 수술  2020-08-07 10:23
# 3            2          폐 기타사항          Y     폐질환으로 수술  2020-08-07 10:23
# 4            2          폐 기타사항          N     폐질환으로 수술  2020-08-07 10:23

# %% [markdown]
# # 사망

# %%
암_사망_정보 = pd.read_csv("../Data/1. 유방암 Fake Data/암_사망_정보.csv",  encoding='CP949')
암_사망_정보.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호      사망일자  주사망원인내용              생성일시
# 0    30     IRB  P00001  20160515      NaN  2020-08-10 18:08
# 1    30     IRB  P00002  20091001      NaN  2020-08-10 18:08
# 2    30     IRB  P00003  20081031      NaN  2020-08-10 18:08
# 3    30     IRB  P00004  20141105      NaN  2020-08-10 18:08
# 4    30     IRB  P00005  20110324      NaN  2020-08-10 18:08

# %% [markdown]
# # 검사
# BRCA2병원변형체검출구분코드 : Pathogenic variant 여부 [1:detected, 2:not detected]

# %%
유방암_검사_BRCA1= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_검사_BRCA1.csv",  encoding='CP949')
유방암_검사_BRCA1.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호  BRCA1검사일자  BRCA1병원변형체검출구분코드  BRCA1미확인변이검출구분코드  \
# 0    30     IRB  P00001   20120926                 2                 1
# 1    30     IRB  P00002   20081017                 1                 2
# 2    30     IRB  P00003   20151006                 2                 1
# 3    30     IRB  P00004   20130525                 2                 2
# 4    30     IRB  P00005   20160128                 2                 2
#
#                생성일시
# 0  2020-08-10 11:30
# 1  2020-08-10 11:30
# 2  2020-08-10 11:30
# 3  2020-08-10 11:30
# 4  2020-08-10 11:30

# %%
유방암_검사_BRCA2= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_검사_BRCA2.csv",  encoding='CP949')
유방암_검사_BRCA2.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호  BRCA2검사일자  BRCA2병원변형체검출구분코드  BRCA2미확인변이검출구분코드  \
# 0    30     IRB  P00001   20120903                 1                 2
# 1    30     IRB  P00002   20150314                 2                 2
# 2    30     IRB  P00003   20131209                 1                 2
# 3    30     IRB  P00004   20110915                 1                 2
# 4    30     IRB  P00005   20150812                 2                 1
#
#                생성일시
# 0  2020-08-10 11:35
# 1  2020-08-10 11:35
# 2  2020-08-10 11:35
# 3  2020-08-10 11:35
# 4  2020-08-10 11:35

# %%
유방암_검사_NGS= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_검사_NGS.csv",  encoding='CP949')
유방암_검사_NGS
# Out:
#        센터코드 IRB승인번호  환자대체번호  NGS패널검사일자                        NGS패널검사결과내용  \
# 0        30     IRB  P00001   20111026                                NaN
# 1        30     IRB  P00002   20080319                                NaN
# 2        30     IRB  P00003   20090708                                NaN
# 3        30     IRB  P00004   20110123     검사결과: MSH6 유전자에서 VUS가 발견되었습니다.
# 4        30     IRB  P00005   20140403                                NaN
# ...     ...     ...     ...        ...                                ...
# 12795    30     IRB  P12796   20110212  검사결과: 검사한 유전자 중에서 미분류변이가 발견되었습니다.
# 12796    30     IRB  P12797   20091012                                NaN
# 12797    30     IRB  P12798   20110512                                NaN
# 12798    30     IRB  P12799   20150312                                NaN
# 12799    30     IRB  P12800   20090112     검사결과: MSH6 유전자에서 VUS가 발견되었습니다.
#
#        NGS패널검사결과상세내용              생성일시
# 0                NaN  2020-08-10 11:41
# 1                NaN  2020-08-10 11:41
# 2                NaN  2020-08-10 11:41
# 3                NaN  2020-08-10 11:41
# 4                NaN  2020-08-10 11:41
# ...              ...               ...
# 12795            NaN  2020-08-10 11:41
# 12796            NaN  2020-08-10 11:41
# 12797            NaN  2020-08-10 11:41
# 12798            NaN  2020-08-10 11:41
# 12799            NaN  2020-08-10 11:41
#
# [12800 rows x 7 columns]

# %%
유방암_검사_영상= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_검사_영상.csv",  encoding='CP949')
유방암_검사_영상
# Out:
#        센터코드 IRB승인번호  환자대체번호 영상검사내부여부    영상검사일자  영상검사코드  영상검사순번  유방암영상검사종류코드  \
# 0        30     IRB  P00001        Y  20151006  L7583B       8            3
# 1        30     IRB  P00002        N  20091021  L7583B      63            9
# 2        30     IRB  P00003        N  20090626   RC301      25            5
# 3        30     IRB  P00004        N  20141213   L7521       5           11
# 4        30     IRB  P00005        Y  20090324   RU301      34            9
# ...     ...     ...     ...      ...       ...     ...     ...          ...
# 12795    30     IRB  P12796        N  20151212   L7521      97           11
# 12796    30     IRB  P12797        N  20120412   L7583       5            9
# 12797    30     IRB  P12798        N  20151212   L7521      25           11
# 12798    30     IRB  P12799        N  20101112   L7521      50           11
# 12799    30     IRB  P12800        N  20111012  L7583B      63            9
#
#                      영상검사종류명 영상검사EDI코드  \
# 0                       SONO       비급여
# 1      기타_Lymphoscintigraphy       비급여
# 2                        MRI     HA464
# 3                  Bone scan     HC191
# 4      기타_Lymphoscintigraphy     E9441
# ...                      ...       ...
# 12795              Bone scan     HC191
# 12796  기타_Lymphoscintigraphy       비급여
# 12797              Bone scan     HC191
# 12798              Bone scan     HC191
# 12799  기타_Lymphoscintigraphy       비급여
#
#                                           영상검사명  영상검사소견내용  영상검사유방암조영술밀도코드  \
# 0                                            \N       NaN               3
# 1                                            \N       NaN              99
# 2                                            \N       NaN               3
# 3      Bone scan(whole body-add material costs)       NaN               4
# 4                                            \N       NaN               2
# ...                                         ...       ...             ...
# 12795  Bone scan(whole body-add material costs)       NaN               1
# 12796                                        \N       NaN              99
# 12797  Bone scan(whole body-add material costs)       NaN               2
# 12798  Bone scan(whole body-add material costs)       NaN               3
# 12799                                        \N       NaN               2
#
#              영상검사유방암조영술밀도코드기타내용  영상검사결과내용              생성일시
# 0         Heterogeneously dense       NaN  2020-08-10 10:48
# 1                         Other       NaN  2020-08-10 10:48
# 2         Heterogeneously dense       NaN  2020-08-10 10:48
# 3               Extremely dense       NaN  2020-08-10 10:48
# 4      Scattered fibroglandular       NaN  2020-08-10 10:48
# ...                         ...       ...               ...
# 12795              Fatty breast       NaN  2020-08-10 10:48
# 12796                     Other       NaN  2020-08-10 10:48
# 12797  Scattered fibroglandular       NaN  2020-08-10 10:48
# 12798     Heterogeneously dense       NaN  2020-08-10 10:48
# 12799  Scattered fibroglandular       NaN  2020-08-10 10:48
#
# [12800 rows x 16 columns]

# %%
유방암_검사_진단= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_검사_진단.csv",  encoding='CP949')
유방암_검사_진단.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호    진단검사일자  유방암진단검사종류코드  진단검사순번 진단검사코드 진단검사EDI코드  \
# 0    30     IRB  P00001  20090522            5      80  L8017       NaN
# 1    30     IRB  P00002  20120724            7       3  L8611       NaN
# 2    30     IRB  P00003  20140413            4      82  L2003     D0002
# 3    30     IRB  P00004  20150510            5      42  L8017       NaN
# 4    30     IRB  P00005  20080820            8      44  L8163     C2210
#
#       진단검사종류명     진단검사종류참고값  진단검사종류참고값단위내용        진단검사명 진단검사결과내용  \
# 0         WBC  4.0~10.0＊103            NaN         WBC         ㎕
# 1   Platelets            \N            NaN           \N       \N
# 2  Hemoglobin         12~16            NaN  Hemoglobin       g/㎗
# 3         WBC  4.0~10.0＊103            NaN         WBC         ㎕
# 4     Albumin       3.3~5.2            NaN     Albumin       g/㎗
#
#               생성일시
# 0  2020-08-10 9:22
# 1  2020-08-10 9:22
# 2  2020-08-10 9:22
# 3  2020-08-10 9:22
# 4  2020-08-10 9:22

# %% [markdown]
# # 병리

# %%
유방암_병리_면역= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_병리_면역.csv",  encoding='CP949')
유방암_병리_면역.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호        병리번호  면역병리검사접수일자  면역병리검사판독일자  면역병리ER검사결과코드  \
# 0    30     IRB  P00001  4012534320    20150220    20150306             3
# 1    30     IRB  P00002  8689460873    20090730    20150721             4
# 2    30     IRB  P00003  5420338928    20160620    20160704             4
# 3    30     IRB  P00004  4880231618    20110205    20151106             2
# 4    30     IRB  P00005  7730472981    20140702    20140716             4
#
#   면역병리ER검사결과코드기타내용  면역병리ER검사결과내용  면역병리ER검사결과점수  ...  면역병리AR검사결과코드  \
# 0              NaN  Strong (8/8)            17  ...             3
# 1              NaN           NaN            16  ...             4
# 2              NaN           NaN            24  ...             1
# 3              NaN  Strong (8/8)            26  ...             3
# 4              NaN           NaN            10  ...             3
#
#    면역병리AR검사결과코드기타내용  면역병리AR검사결과내용 면역병리AR검사결과점수 면역병리AR검사결과총점수  면역병리AR검사결과값  \
# 0               NaN           NaN           62            78         12.1
# 1               NaN           NaN           55            80         12.1
# 2               NaN  Strong (8/8)           81            36        100.0
# 3               NaN           NaN           35            24         99.1
# 4               NaN           NaN           43            63        100.0
#
#    면역병리HER2검사결과내용  면역병리P53검사결과내용  면역병리KI67검사결과내용              생성일시
# 0             NaN            NaN             NaN  2020-08-10 12:49
# 1              3+            NaN             NaN  2020-08-10 12:49
# 2             NaN            NaN             NaN  2020-08-10 12:49
# 3             NaN            NaN             NaN  2020-08-10 12:49
# 4              3+            NaN             NaN  2020-08-10 12:49
#
# [5 rows x 28 columns]

# %%
유방암_병리_분자= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_병리_분자.csv",  encoding='CP949')
유방암_병리_분자.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호  분자병리접수일자  분자병리판독일자  분자병리순번 분자병리검사방법내용 분자병리검사결과내용  \
# 0    30     IRB  P00001  20121000  20141011       3        NaN        NaN
# 1    30     IRB  P00002  20150900  20160117      92       FISH        NaN
# 2    30     IRB  P00003  20100300  20120604      36        NaN   Positive
# 3    30     IRB  P00004  20110800  20080904      15       SISH        NaN
# 4    30     IRB  P00005  20130500  20151130      16        NaN        NaN
#
#    분자병리검사종양세포핵수  분자병리검사HER2평균수  분자병리검사CEP17평균수  분자병리HER2CEP17비율  \
# 0            27              5              49              0.8
# 1            62             68              42              0.6
# 2            57             64              76              0.2
# 3            12             65              78              0.4
# 4            97             68              31              0.5
#
#                생성일시
# 0  2020-08-10 13:11
# 1  2020-08-10 13:11
# 2  2020-08-10 13:11
# 3  2020-08-10 13:11
# 4  2020-08-10 13:11

# %%
유방암_병리_생검= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_병리_생검.csv",  encoding='CP949')
유방암_병리_생검.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호        병리번호  생체검사순번 생체검사원내시행여부  병리생체검사접수일자  생체검사판독일자  \
# 0    30     IRB  P00001  3456029593      17          Y    20150108  20150122
# 1    30     IRB  P00002  7005947709      64          N    20080219  20130922
# 2    30     IRB  P00003  7029960453      31          N    20120908  20120922
# 3    30     IRB  P00004  5874120950      47          N    20150408  20150422
# 4    30     IRB  P00005  9780543267      19          Y    20100109  20100123
#
#      생체검사부위내용       생체검사위치내용 생체검사방법내용                  생체검사결과내용  생체검사조직학적등급수  \
# 0  Lymph node            NaN      NaN                       NaN           33
# 1         NaN  Right 9 to 11      NaN                       NaN           42
# 2  Lymph node            NaN      NaN                       NaN           21
# 3         NaN            NaN      NaN  nvasive ductal carcinoma            5
# 4  Lymph node            NaN      NaN                       NaN           58
#
#                생성일시
# 0  2020-08-10 12:36
# 1  2020-08-10 12:36
# 2  2020-08-10 12:36
# 3  2020-08-10 12:36
# 4  2020-08-10 12:36

# %%
유방암_병리_외과= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_병리_외과.csv",  encoding='CP949')
유방암_병리_외과.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호  외과병리접수일자  외과병리판독일자  외과병리순번  외과병리주채취부위코드  외과병리주채취부위명  \
# 0    30     IRB  P00001  20110420  20141112      44            1      breast
# 1    30     IRB  P00002  20150127  20150210      97            2  lymph node
# 2    30     IRB  P00003  20090330  20120521      47            2  lymph node
# 3    30     IRB  P00004  20140627  20140711      11            1      breast
# 4    30     IRB  P00005  20140730  20140813      41            2  lymph node
#
#    외과병리수술위치내용 외과병리유방종양크기값  ... 외과병리림프절전이암크기값 외과병리혈관성침윤내용     외과병리림프성침윤내용  \
# 0         NaN       0.1cm  ...            93     Unknown         present
# 1      Breast         NaN  ...           143      absent          absent
# 2  lumpectomy       1.5cm  ...           944     present  absent/present
# 3         NaN       0.1cm  ...           128     Unknown         Unknown
# 4  lumpectomy       1.5cm  ...           498     present         Unknown
#
#   외과병리종양변두리내용 외과병리미세석회화내용  외과병리초치료재발구분코드 외과병리병리학적T병기값 외과병리병리학적N병기값 외과병리추가판독내용  \
# 0         NaN     Unknown              2          416          528        NaN
# 1         NaN      absent              2          270          192        NaN
# 2         NaN     present              1          272          232        NaN
# 3         NaN     Unknown              2           15          461        NaN
# 4         NaN     present              1          228          416        NaN
#
#                생성일시
# 0  2020-08-10 14:21
# 1  2020-08-10 14:21
# 2  2020-08-10 14:21
# 3  2020-08-10 14:21
# 4  2020-08-10 14:21
#
# [5 rows x 40 columns]

# %% [markdown]
# # 수술

# %%
유방암_수술_기타= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_수술_기타.csv",  encoding='CP949')
유방암_수술_기타.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호    기타수술일자  기타수술순번  기타수술구분코드  기타수술구분코드기타내용    기타수술구분명  \
# 0    30     IRB  P00001  20120309      18        99           NaN  기타수술(타부위)
# 1    30     IRB  P00002  20150705      89         1           NaN  Chemoport
# 2    30     IRB  P00003  20160619      76         1           NaN  Chemoport
# 3    30     IRB  P00004  20111007      59         2           NaN    수술 후 처치
# 4    30     IRB  P00005  20100710      41        99           NaN  기타수술(타부위)
#
#    유방암수술종류코드    수술코드                                                수술명  \
# 0          1   JI793                       Removal of implant of breast
# 1          1  JN7131                                 Mastectomy(simple)
# 2          5  JN7131                                 Mastectomy(simple)
# 3         99  JN7121  Excision or destruction of breast tissue, not ...
# 4         99   JI793                       Removal of implant of breast
#
#                생성일시
# 0  2020-08-10 15:53
# 1  2020-08-10 15:53
# 2  2020-08-10 15:53
# 3  2020-08-10 15:53
# 4  2020-08-10 15:53

# %%
유방암_수술_이전소견= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_수술_이전소견.csv",  encoding='CP949')
유방암_수술_이전소견.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호   수술전소견일자  수술전순번 수술전무증상여부 수술전유방통증여부 수술전유방혹여부  \
# 0    30     IRB  P00001  20130523     89        Y         N        N
# 1    30     IRB  P00002  20150421     26        Y         N        Y
# 2    30     IRB  P00003  20151106     12        N         Y        N
# 3    30     IRB  P00004  20080423      5        N         N        Y
# 4    30     IRB  P00005  20091021     43        Y         Y        N
#
#   수술전액와부통증여부 수술전액와부혹여부 수술전유두분비물여부 수술전기타증상여부              생성일시
# 0          Y         N          Y         Y  2020-08-10 16:31
# 1          Y         N          Y         N  2020-08-10 16:31
# 2          Y         N          N         Y  2020-08-10 16:31
# 3          N         N          Y         Y  2020-08-10 16:31
# 4          N         Y          Y         N  2020-08-10 16:31

# %%
유방암_수술_이후합병증= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_수술_이후합병증.csv",  encoding='CP949')
유방암_수술_이후합병증.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호   합병증기록일자  유방암수술후순번  유방암수술후상처감염내용  유방암수술후장액종내용  \
# 0    30     IRB  P00001  20111026        26           NaN          NaN
# 1    30     IRB  P00002  20090810        61           NaN          NaN
# 2    30     IRB  P00003  20140830        21           NaN          NaN
# 3    30     IRB  P00004  20080303        86           NaN          NaN
# 4    30     IRB  P00005  20161025        29           NaN          NaN
#
#    유방암수술후피부괴사내용  유방암수술후운동제한내용  유방암수술후액와부수축내용  유방암수술후팔부종내용  유방암수술후신경손상내용  \
# 0           NaN           NaN            NaN          NaN           NaN
# 1           NaN           NaN            NaN          NaN           NaN
# 2           NaN           NaN            NaN          NaN           NaN
# 3           NaN           NaN            NaN          NaN           NaN
# 4           NaN           NaN            NaN          NaN           NaN
#
#    유방암수술후출혈내용  유방암수술후기타합병증내용              생성일시
# 0         NaN            NaN  2020-08-10 16:39
# 1         NaN            NaN  2020-08-10 16:39
# 2         NaN            NaN  2020-08-10 16:39
# 3         NaN            NaN  2020-08-10 16:39
# 4         NaN            NaN  2020-08-10 16:39

# %%
유방암_수술_자궁난소= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_수술_자궁난소.csv",  encoding='CP949')
유방암_수술_자궁난소.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호  양측난관순번  양측난관난소절제술수술일자 양측난관난소절제술여부 자궁절제술여부  \
# 0    30     IRB  P00001      18       20091106           Y       Y
# 1    30     IRB  P00002      48       20130401           N       Y
# 2    30     IRB  P00003      75       20100717           N       Y
# 3    30     IRB  P00004      83       20090214           N       Y
# 4    30     IRB  P00005      57       20120306           Y       Y
#
#                생성일시
# 0  2020-08-10 16:35
# 1  2020-08-10 16:35
# 2  2020-08-10 16:35
# 3  2020-08-10 16:35
# 4  2020-08-10 16:35

# %%
유방암_수술_정보= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_수술_정보.csv",  encoding='CP949')
유방암_수술_정보.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호      수술일자  수술순번   진료기록ID    수술입원일자    수술퇴원일자  \
# 0    30     IRB  P00001  20141209    42  9795093  20141125  20141209
# 1    30     IRB  P00002  20080922    99  7698228  20160420  20160504
# 2    30     IRB  P00003  20091109    55  4324701  20121004  20121018
# 3    30     IRB  P00004  20081129    49  2375151  20081115  20120514
# 4    30     IRB  P00005  20100803    49  5621690  20160608  20160622
#
#    유방암수술종류코드      수술코드  ... 수술시피부침윤내용 수술시흉근침윤내용 수술시감시림프절생체검사방법내용 수술시감시림프절수  \
# 0         99  20062044  ...       NaN       NaN                2        47
# 1          1  20003681  ...       NaN       NaN                9        53
# 2          1  20003681  ...       NaN       NaN                1        34
# 3          2  20003679  ...       NaN       NaN                1        32
# 4          5  20004115  ...       NaN       NaN                8        84
#
#   수술시액와부림프절절제범위내용 수술시배액관내용 수술시배액관종류내용 수술시유방재건술내용  수술시유방재건재료내용  \
# 0             NaN      NaN        NaN        NaN          NaN
# 1     Left: Level      NaN        NaN  Bilateral          NaN
# 2             NaN      NaN        NaN        NaN          NaN
# 3             NaN      NaN        NaN        NaN          NaN
# 4     Left: Level      NaN        NaN  Bilateral          NaN
#
#                생성일시
# 0  2020-08-14 15:58
# 1  2020-08-14 15:58
# 2  2020-08-14 15:58
# 3  2020-08-14 15:58
# 4  2020-08-14 15:58
#
# [5 rows x 36 columns]

# %% [markdown]
# # 진단

# %%
유방암_진단_ONCOTYPE= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_진단_ONCOTYPE.csv",  encoding='CP949')
유방암_진단_ONCOTYPE.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호  온코형순번 외부검사여부  온코형점수내용  온코형점수  온코형점수총점수  온코형점수값  \
# 0    30     IRB  P00001     16      Y      NaN     72        95   100.0
# 1    30     IRB  P00002     85      Y      NaN     36        82    12.1
# 2    30     IRB  P00003     64      N      NaN     34        75    12.1
# 3    30     IRB  P00004     16      N      NaN     13        74    12.1
# 4    30     IRB  P00005     66      Y      NaN     25        12    99.1
#
#                생성일시
# 0  2020-08-07 17:56
# 1  2020-08-07 17:56
# 2  2020-08-07 17:56
# 3  2020-08-07 17:56
# 4  2020-08-07 17:56

# %%
유방암_진단_신체계측정보= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_진단_신체계측정보.csv",  encoding='CP949')
유방암_진단_신체계측정보.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호  신체계측기록일자  신체계측순번    신장측정일자    신장값    체중측정일자  체중측정값  \
# 0    30     IRB  P00001  20080308      83  20080207   99.1  20080228   12.1
# 1    30     IRB  P00002  20121022      66  20080101   55.1  20080128   12.1
# 2    30     IRB  P00003  20100226      76  20100127  100.0  20100128   55.1
# 3    30     IRB  P00004  20150526      13  20150426   55.1  20150428   99.1
# 4    30     IRB  P00005  20140106      71  20131207   12.1  20131228   12.1
#
#      BMI값  ECOG코드                     ECOG코드기타내용              생성일시
# 0  100.00      99                             기타  2020-08-07 15:36
# 1   99.11       4                   계속 누워 있어야 한다  2020-08-07 15:36
# 2   12.10      99                             기타  2020-08-07 15:36
# 3  100.00       0                     제한없이 정상적이다  2020-08-07 15:36
# 4   99.11       2  증상이 있으나 누워 지내는 시간은 하루의 반보다 적다  2020-08-07 15:36

# %%
유방암_진단_재발정보= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_진단_재발정보.csv",  encoding='CP949')
유방암_진단_재발정보.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호    재발진단일자  재발정보순번  재발확인기간일수  재발부위내용  기타재발내용  재발치료코드  \
# 0    30     IRB  P00001  20130300      45       311     NaN     NaN       0
# 1    30     IRB  P00002  20140400      72       290     NaN     NaN      99
# 2    30     IRB  P00003  20100200      77        83     NaN     NaN       2
# 3    30     IRB  P00004  20110600      49       212     NaN     NaN       3
# 4    30     IRB  P00005  20110100      44        92     NaN     NaN       1
#
#    재발치료코드기타내용         재발치료명  재발추가치료내용              생성일시
# 0         NaN            No       NaN  2020-08-10 18:31
# 1         NaN         Other       NaN  2020-08-10 18:31
# 2         NaN  Chemotherapy       NaN  2020-08-10 18:31
# 3         NaN     Operation       NaN  2020-08-10 18:31
# 4         NaN  Radiotherapy       NaN  2020-08-10 18:31

# %%
유방암_진단_전이정보= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_진단_전이정보.csv",  encoding='CP949')
유방암_진단_전이정보.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호    전이진단일자  전이정보순번  전이부위내용  기타전이부위내용  전이치료코드  \
# 0    30     IRB  P00001  20130102      73     NaN       NaN      99
# 1    30     IRB  P00002  20110723      28     NaN       NaN       3
# 2    30     IRB  P00003  20141018      53     NaN       NaN       3
# 3    30     IRB  P00004  20120429      48     NaN       NaN       2
# 4    30     IRB  P00005  20130307      18     NaN       NaN       3
#
#    전이치료코드기타내용         전이치료명  전이추가치료내용              생성일시
# 0         NaN         Other       NaN  2020-08-10 18:22
# 1         NaN     Operation       NaN  2020-08-10 18:22
# 2         NaN     Operation       NaN  2020-08-10 18:22
# 3         NaN  Chemotherapy       NaN  2020-08-10 18:22
# 4         NaN     Operation       NaN  2020-08-10 18:22

# %%
유방암_진단_정보= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_진단_정보.csv",  encoding='CP949')
유방암_진단_정보.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호      진단일자 진단코드 유방암진단명종류코드  진단영문명  \
# 0    30     IRB  P00001  20161021  EDI        D11    NaN
# 1    30     IRB  P00002  20151217  EDI        C63    NaN
# 2    30     IRB  P00003  20120831  EDI        D05    NaN
# 3    30     IRB  P00004  20161226  EDI        D14    NaN
# 4    30     IRB  P00005  20081129  EDI        C82    NaN
#
#                               진단한글명  유방암진단구분코드  유방암진단구분코드기타내용 진단구분명  \
# 0                D11 (주타액선의 양성 신생물)         99            NaN    기타
# 1  C63 (기타 및 상세불명의 남성 생식기관의 악성 신생물)         99            NaN    기타
# 2                  D05 (유방의 상피내 암종)         99            NaN    기타
# 3            D14 (중이 및 호흡기계의 양성신생물)         99            NaN    기타
# 4           C82 (여포성(결절성) 비호지킨 림프종)          1            NaN   유방암
#
#                생성일시
# 0  2020-08-07 15:48
# 1  2020-08-07 15:48
# 2  2020-08-07 15:48
# 3  2020-08-07 15:48
# 4  2020-08-07 15:48

# %%
유방암_진단_초기병기= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_진단_초기병기.csv",  encoding='CP949')
유방암_진단_초기병기.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호    병기기록일자  초기임상검사T병기값  초기임상검사N병기값  초기임상검사M병기값  \
# 0    30     IRB  P00001  20160219         839          32         148
# 1    30     IRB  P00002  20150422         346         244          13
# 2    30     IRB  P00003  20090217          16         390         229
# 3    30     IRB  P00004  20120730         868          39         580
# 4    30     IRB  P00005  20080827         414         520         220
#
#    초기임상검사병기값  종양크기값  종양크기값출처내용              생성일시
# 0        492    511        NaN  2020-08-07 17:13
# 1        238     80        NaN  2020-08-07 17:13
# 2        281    556        NaN  2020-08-07 17:13
# 3        750     14        NaN  2020-08-07 17:13
# 4        234    672        NaN  2020-08-07 17:13

# %%
유방암_진단_특이임상소견= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_진단_특이임상소견.csv",  encoding='CP949')
유방암_진단_특이임상소견.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호  특이임상소견서순번 특이임상소견기타부위암종여부 특이임상소견양측성유방암여부 특이임상임신여부  \
# 0    30     IRB  P00001         41              N              N        N
# 1    30     IRB  P00002         63              N              N        Y
# 2    30     IRB  P00003         25              Y              Y        N
# 3    30     IRB  P00004         96              Y              Y        Y
# 4    30     IRB  P00005         81              Y              Y        N
#
#               생성일시
# 0  2020-08-10 9:17
# 1  2020-08-10 9:17
# 2  2020-08-10 9:17
# 3  2020-08-10 9:17
# 4  2020-08-10 9:17

# %%
유방암_진단_협진의뢰= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_진단_협진의뢰.csv",  encoding='CP949')
유방암_진단_협진의뢰.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호    협진의뢰일자 협진의뢰과코드 협진회신과코드  협진순번 협진여부       협진의뢰과명  \
# 0    30     IRB  P00001  20081107    BRHO    BRED    24    N   (유방)혈액종양내과
# 1    30     IRB  P00002  20080508    BRRO    BRBS    76    Y  (유방)방사선종양학과
# 2    30     IRB  P00003  20121118    BRBS    BRIS    50    Y        유방암외과
# 3    30     IRB  P00004  20120224      BR    BRHO    82    N        유방암센터
# 4    30     IRB  P00005  20081219    BRBS    BRES    93    Y        유방암외과
#
#             협진회신과명  협진내용              생성일시
# 0            내분비내과   NaN  2020-08-07 17:02
# 1            유방암외과   NaN  2020-08-07 17:02
# 2  (유방)암생존자통합지지클리닉   NaN  2020-08-07 17:02
# 3       (유방)혈액종양내과   NaN  2020-08-07 17:02
# 4            내분비외과   NaN  2020-08-07 17:02

# %% [markdown]
# # 치료

# %%
유방암_치료_기타약제= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_치료_기타약제.csv",  encoding='CP949')
유방암_치료_기타약제.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호 약품코드    약품처방일자  약품처방순번  유방암약품종류코드 약품EDI코드  \
# 0    30     IRB  P00001  EDI  20111031      32         13     EDI
# 1    30     IRB  P00002  EDI  20111120      53         14     EDI
# 2    30     IRB  P00003  EDI  20140519      60         31     EDI
# 3    30     IRB  P00004  EDI  20111112      73         10     EDI
# 4    30     IRB  P00005  EDI  20100916       3          9     EDI
#
#              약품명              생성일시
# 0  Epoetin-alpha  2020-08-10 17:59
# 1     Filgrastim  2020-08-10 17:59
# 2    Pravastatin  2020-08-10 17:59
# 3     Enoxaparin  2020-08-10 17:59
# 4      Enalapril  2020-08-10 17:59

# %%
유방암_치료_방사선= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_치료_방사선.csv",  encoding='CP949')
유방암_치료_방사선.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호  방사선치료시작일자  방사선치료순번  방사선치료종료일자  방사선치료RT번호  방사선치료기간일수  \
# 0    30     IRB  P00001   20111209       69   20150811        310         77
# 1    30     IRB  P00002   20110911       77   20111002        333         70
# 2    30     IRB  P00003   20100127       36   20150704         18         63
# 3    30     IRB  P00004   20161204       55   20161225         35          7
# 4    30     IRB  P00005   20140801       82   20140822         98         72
#
#    방사선치료부위종류코드  방사선치료부위종류코드기타내용  ...         방사선치료처방명 방사선치료부위코드  \
# 0            3              NaN  ...        SRS 8port        10
# 1            7              NaN  ...        SRS 7port        22
# 2           99              NaN  ...  Conformal 7port        10
# 3           99              NaN  ...   Electron 4Port        22
# 4            5              NaN  ...  6MV X-RAY 3Port      9999
#
#           방사선치료부위명 방사선치료목적코드 방사선치료목적코드기타내용    방사선치료목적명 방사선치료1회선량  방사선치료총치료횟수  \
# 0      Brain Whole        99           NaN       Other      5531        6269
# 1  Brain Partial 3        99           NaN       Other      3601        3502
# 2      Brain Whole        99           NaN       Other      9922        8876
# 3  Brain Partial 3         1           NaN    Curative      3740        5905
# 4            Other         2           NaN  Palliative       821        2241
#
#    방사선치료총선량              생성일시
# 0      8304  2020-08-10 17:38
# 1       916  2020-08-10 17:38
# 2      1073  2020-08-10 17:38
# 3       999  2020-08-10 17:38
# 4      6904  2020-08-10 17:38
#
# [5 rows x 24 columns]

# %%
유방암_치료_항암제= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_치료_항암제.csv",  encoding='CP949')
유방암_치료_항암제.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호 항암제코드  항암치료처방일자  항암제처방순번  항암치료목적코드     항암치료목적명  \
# 0    30     IRB  P00001   EDI  20140717       44         5   Induction
# 1    30     IRB  P00002   EDI  20120928      100        99       Other
# 2    30     IRB  P00003   EDI  20160508       23         2    adjuvant
# 3    30     IRB  P00004   EDI  20141031       28         4  Concurrent
# 4    30     IRB  P00005   EDI  20150831       55         2    adjuvant
#
#    유방암항암성분명종류코드         항암성분종류명  ... 항암제용량  항암치료시작일자  항암치료종료일자  항암치료용량  환자신장값  \
# 0            25       Lapatinib  ...    51  20120106  20100318      82   12.1
# 1            16     Doxorubicin  ...    36  20090209  20120124      10   55.1
# 2             6  Nab-Paclitaxel  ...    45  20151123  20091125      68  100.0
# 3             7        Abraxane  ...    73  20140409  20100218      16   55.1
# 4            21           T-DM1  ...    93  20140224  20160519      75   99.1
#
#    환자체중값  항암치료용법명  항암치료주기값 항암치료주기상태내용              생성일시
# 0   12.1      NaN       79     완료하지못함  2020-08-10 16:45
# 1   99.1      NaN      198        진행중  2020-08-10 16:45
# 2   99.1      NaN      740         완료  2020-08-10 16:45
# 3  100.0      NaN      853        NaN  2020-08-10 16:45
# 4  100.0      NaN      979        진행중  2020-08-10 16:45
#
# [5 rows x 22 columns]

# %%
유방암_치료_호르몬제= pd.read_csv("../Data/1. 유방암 Fake Data/유방암_치료_호르몬제.csv",  encoding='CP949')
유방암_치료_호르몬제.head()
# Out:
#    센터코드 IRB승인번호  환자대체번호  호르몬치료처방일자  호르몬치료순번 호르몬치료제코드 호르몬치료기록여부  호르몬치료시작일자  \
# 0    30     IRB  P00001   20160101       47      NaN         N   20160502
# 1    30     IRB  P00002   20110811       18      NaN         N   20140315
# 2    30     IRB  P00003   20140715       42      NaN         N   20090616
# 3    30     IRB  P00004   20130605       98      NaN         N   20160119
# 4    30     IRB  P00005   20081204       20      NaN         N   20160521
#
#    호르몬치료종료일자  호르몬치료목적코드  호르몬치료목적코드기타내용 호르몬치료목적코드기타내용.1  유방암호르몬치료제성분명종류코드  \
# 0   20081202         99            NaN           Other                 4
# 1   20130304         99            NaN           Other                 1
# 2   20141107         99            NaN           Other                 1
# 3   20150614          7            NaN      Concurrent                 4
# 4   20111211         99            NaN           Other                 2
#
#       호르몬치료성분명 호르몬치료제EDI코드 호르몬치료제명  호르몬치료제용량  항암치료용량  호르몬치료기간일수  \
# 0  Anastrozole         NaN     NaN        88      47         66
# 1    Tamoxifen         NaN     NaN         9      86         47
# 2    Tamoxifen         NaN     NaN        21      80         91
# 3  Anastrozole         NaN     NaN         5      15         42
# 4    Letrozole         NaN     NaN        63      27          8
#
#                생성일시
# 0  2020-08-10 17:04
# 1  2020-08-10 17:04
# 2  2020-08-10 17:04
# 3  2020-08-10 17:04
# 4  2020-08-10 17:04
